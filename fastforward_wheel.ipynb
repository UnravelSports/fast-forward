# %%
import fastforward
from fastforward import sportec
print(fastforward.__version__)
# Out:
# 0.1.0

# %%
dataset = sportec.load_tracking_imp(
    raw_data="data/sportec/MLS-MAT-0005WA_tracking.xml",
    meta_data="data/sportec/MLS-MAT-0005WA_match_info.xml",
)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 dataset = sportec.load_tracking_imp(
#       2     raw_data="data/sportec/MLS-MAT-0005WA_tracking.xml",
#       3     meta_data="data/sportec/MLS-MAT-0005WA_match_info.xml",
#       4 )
#
# AttributeError: module 'fastforward.sportec' has no attribute 'load_tracking_imp'

# %%
dataset.metadata
# Out:
# shape: (1, 12)
# ┌──────────┬────────────┬────────────┬────────────┬───┬────────────┬──────┬────────────┬───────────┐
# │ provider ┆ game_id    ┆ game_date  ┆ home_team  ┆ … ┆ pitch_widt ┆ fps  ┆ coordinate ┆ orientati │
# │ ---      ┆ ---        ┆ ---        ┆ ---        ┆   ┆ h          ┆ ---  ┆ _system    ┆ on        │
# │ str      ┆ str        ┆ date       ┆ str        ┆   ┆ ---        ┆ f32  ┆ ---        ┆ ---       │
# │          ┆            ┆            ┆            ┆   ┆ f32        ┆      ┆ str        ┆ str       │
# ╞══════════╪════════════╪════════════╪════════════╪═══╪════════════╪══════╪════════════╪═══════════╡
# │ sportec  ┆ MLS-MAT-00 ┆ 2025-04-06 ┆ San Diego  ┆ … ┆ 68.0       ┆ 25.0 ┆ cdf        ┆ static_ho │
# │          ┆ 05WA       ┆            ┆ FC         ┆   ┆            ┆      ┆            ┆ me_away   │
# └──────────┴────────────┴────────────┴────────────┴───┴────────────┴──────┴────────────┴───────────┘
