# %%
from kloppy_light import sportec

# %%
dataset = sportec.load_tracking_impl(
    raw_data="data/sportec/MLS-MAT-0005WA_tracking.xml",
    meta_data="data/sportec/MLS-MAT-0005WA_match_info.xml",
)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 dataset = sportec.load_tracking_impl(
#       2     raw_data="data/sportec/MLS-MAT-0005WA_tracking.xml",
#       3     meta_data="data/sportec/MLS-MAT-0005WA_match_info.xml",
#       4 )
#
# TypeError: load_tracking_impl() missing 7 required positional arguments: 'provider_name', 'layout', 'coordinates', 'orientation', 'only_alive', 'include_game_id', and 'lazy'

# %%
dataset.tracking
# Out:
# shape: (1_971_514, 11)
# ┌─────────────┬──────────┬───────────┬─────────────┬───┬────────────┬───────────┬───────────┬──────┐
# │ game_id     ┆ frame_id ┆ period_id ┆ timestamp   ┆ … ┆ player_id  ┆ x         ┆ y         ┆ z    │
# │ ---         ┆ ---      ┆ ---       ┆ ---         ┆   ┆ ---        ┆ ---       ┆ ---       ┆ ---  │
# │ str         ┆ u32      ┆ i32       ┆ duration[ms ┆   ┆ str        ┆ f32       ┆ f32       ┆ f32  │
# │             ┆          ┆           ┆ ]           ┆   ┆            ┆           ┆           ┆      │
# ╞═════════════╪══════════╪═══════════╪═════════════╪═══╪════════════╪═══════════╪═══════════╪══════╡
# │ MLS-MAT-000 ┆ 10001    ┆ 1         ┆ 0ms         ┆ … ┆ ball       ┆ -0.62     ┆ 0.48      ┆ 0.01 │
# │ 5WA         ┆          ┆           ┆             ┆   ┆            ┆           ┆           ┆      │
# │ MLS-MAT-000 ┆ 10001    ┆ 1         ┆ 0ms         ┆ … ┆ MLS-OBJ-00 ┆ -42.98    ┆ 0.26      ┆ 0.0  │
# ...
